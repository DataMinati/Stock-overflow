# %% [markdown]
# <a href="https://colab.research.google.com/github/DataMinati/Stock-overflow/blob/main/M2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Module 2: Exploration data analysis of visualization and training a model by given attributes

# %%
#import library packages
import pandas as p
import matplotlib.pyplot as plt
import seaborn as s
import numpy as n

# %%
data = p.read_csv("/content/combined_stock_data.csv")

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df=data.dropna()

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'Label', 'Top1', 'Top2', 'Top3', 'Top4', 'Top5',
#        'Top6', 'Top7', 'Top8', 'Top9', 'Top10', 'Top11', 'Top12', 'Top13',
#        'Top14', 'Top15', 'Top16', 'Top17', 'Top18', 'Top19', 'Top20', 'Top21',
#        'Top22', 'Top23', 'Top24', 'Top25', 'Para', 'Subjectivity',
#        'Objectivity', 'Positive', 'Neutral', 'Negative'],
#       dtype='object')

# %%
p.crosstab(df.Label,df.Subjectivity)
# Out:
# Subjectivity  0.000000    6.666667    8.333333    9.090909    12.500000   \
# Label
# 0                      1           1           2           0           2
# 1                      1           0           0           1           0
#
# Subjectivity  13.333333   14.285714   15.789474   16.666667   18.181818   ...  \
# Label                                                                     ...
# 0                      3           1           1           2           3  ...
# 1                      0           0           0           8           0  ...
#
# Subjectivity  80.000000   81.818182   83.333333   85.714286   87.500000   \
# Label
# 0                     28           0          32           6           4
# 1                     38           1          17          10           7
#
# Subjectivity  88.888889   90.000000   91.666667   92.857143   100.000000
# Label
# 0                      3           0           0           1          96
# 1                      2           2           1           0          89
#
# [2 rows x 121 columns]

# %%
#Histogram Plot of Age distribution
df['Label'].hist(figsize=(7,6), color='green', alpha=0.7)
plt.xlabel('Label')
plt.ylabel('News')
plt.title('Lebel of distribution of News')
# Out:
# Text(0.5, 1.0, 'Lebel of distribution of News')

# %%
#Histogram Plot of Age distribution
df['Subjectivity'].hist(figsize=(7,6), color='green', alpha=0.7)
plt.xlabel('Subjectivity')
plt.ylabel('News')
plt.title('Subjectivity of distribution of News')
# Out:
# Text(0.5, 1.0, 'Subjectivity of distribution of News')

# %%
#Histogram Plot of Age distribution
df['Objectivity'].hist(figsize=(7,6), color='green', alpha=0.7)
plt.xlabel('Objectivity')
plt.ylabel('News')
plt.title('Objectivity of distribution of News')
# Out:
# Text(0.5, 1.0, 'Objectivity of distribution of News')

# %%
#Histogram Plot of Age distribution
df['Positive'].hist(figsize=(7,6), color='green', alpha=0.7)
plt.xlabel('Positive')
plt.ylabel('News')
plt.title('Positive of distribution of News')
# Out:
# Text(0.5, 1.0, 'Positive of distribution of News')

# %%
#Histogram Plot of Age distribution
df['Neutral'].hist(figsize=(7,6), color='green', alpha=0.7)
plt.xlabel('Neutral')
plt.ylabel('News')
plt.title('Neutral of distribution of News')
# Out:
# Text(0.5, 1.0, 'Neutral of distribution of News')

# %%
#Histogram Plot of Age distribution
df['Negative'].hist(figsize=(7,6), color='green', alpha=0.7)
plt.xlabel('Negative')
plt.ylabel('News')
plt.title('Negative of distribution of News')
# Out:
# Text(0.5, 1.0, 'Negative of distribution of News')

# %%
#Propagation by variable
def PropByVar(df, variable):
    dataframe_pie = df[variable].value_counts()
    ax = dataframe_pie.plot.pie(figsize=(10,10), autopct='%1.2f%%', fontsize = 12)
    ax.set_title(variable + ' \n', fontsize = 15)
    return n.round(dataframe_pie/df.shape[0]*100,2)
PropByVar(df, 'Label')
# Out:
# 1    53.47
# 0    46.53
# Name: Label, dtype: float64

# %%
#Propagation by variable
def PropByVar(df, variable):
    dataframe_pie = df[variable].value_counts()
    ax = dataframe_pie.plot.pie(figsize=(10,10), autopct='%1.2f%%', fontsize = 12)
    ax.set_title(variable + ' \n', fontsize = 15)
    return n.round(dataframe_pie/df.shape[0]*100,2)

PropByVar(df, 'Objectivity')
# Out:
# 50.000000    11.13
# 0.000000      9.32
# 33.333333     7.80
# 40.000000     4.83
# 66.666667     4.23
#              ...
# 84.210526     0.05
# 64.000000     0.05
# 7.142857      0.05
# 43.478261     0.05
# 90.909091     0.05
# Name: Objectivity, Length: 121, dtype: float64

# %%
PropByVar(df, 'Subjectivity')
# Out:
# 50.000000     11.13
# 100.000000     9.32
# 66.666667      7.80
# 60.000000      4.83
# 33.333333      4.23
#               ...
# 15.789474      0.05
# 36.000000      0.05
# 92.857143      0.05
# 56.521739      0.05
# 9.090909       0.05
# Name: Subjectivity, Length: 121, dtype: float64

# %%
# Heatmap plot diagram
fig, ax = plt.subplots(figsize=(15,10))
s.heatmap(df.corr(), ax=ax, annot=True)

# %%
plt.plot(df["Label"], df["Objectivity"], color='g')
plt.xlabel('Patient Age Details')
plt.ylabel('Gender Details')
plt.title('Patient Age Details by gender')
plt.show()

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'Label', 'Top1', 'Top2', 'Top3', 'Top4', 'Top5',
#        'Top6', 'Top7', 'Top8', 'Top9', 'Top10', 'Top11', 'Top12', 'Top13',
#        'Top14', 'Top15', 'Top16', 'Top17', 'Top18', 'Top19', 'Top20', 'Top21',
#        'Top22', 'Top23', 'Top24', 'Top25', 'Para', 'Subjectivity',
#        'Objectivity', 'Positive', 'Neutral', 'Negative'],
#       dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder
var_mod = ['Date', 'Label', 'Top1', 'Top2', 'Top3', 'Top4', 'Top5',
       'Top6', 'Top7', 'Top8', 'Top9', 'Top10', 'Top11', 'Top12', 'Top13',
       'Top14', 'Top15', 'Top16', 'Top17', 'Top18', 'Top19', 'Top20', 'Top21',
       'Top22', 'Top23', 'Top24', 'Top25', 'Para', 'Subjectivity',
       'Objectivity', 'Positive', 'Neutral', 'Negative']
le = LabelEncoder()
for i in var_mod:
    df[i] = le.fit_transform(df[i]).astype(str)

# %%
df.head()
# Out:
#    Unnamed: 0  Date Label Top1  Top2  Top3  Top4  Top5  Top6  Top7  ... Top22  \
# 0        1988  1508     1   84   624  1277   327    50   242   230  ...  1232
# 1        1987  1468     1  755  1203   270  1195  1227   994  1061  ...  1438
# 2        1986  1455     1  501  1503  1358   431   264    83   865  ...   591
# 3        1985  1449     1   60  1303  1115   634   274   244   636  ...    17
# 4        1984  1444     0  256  1023  1010  1344  1160  1210   940  ...   388
#
#   Top23 Top24 Top25 Para Subjectivity Objectivity Positive Neutral Negative
# 0  1447    71   984   84           95          25        0      25       99
# 1  1466  1393   787  755          120           0       96       0        0
# 2   447   205  1336  501          111           9        0       9      106
# 3   245    59   850   60           64          56        0      56       84
# 4   403   901  1000  256           42          78       36      78       34
#
# [5 rows x 34 columns]

# %% [markdown]
# Spliting Train/Test:

# %%
#preprocessing, split test and dataset, split response variable
X = df.drop(labels='Label', axis=1)
#Response variable
y = df.loc[:,'Label']

# %%
#We'll use a test size of 30%. We also stratify the split on the response variable, which is very important to do because there are so few fraudulent transactions.
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1, stratify=y)
print("Number of training dataset: ", len(X_train))
print("Number of test dataset: ", len(X_test))
print("Total number of dataset: ", len(X_train)+len(X_test))
# Out:
# Number of training dataset:  1390
# Number of test dataset:  596
# Total number of dataset:  1986

# %%
def qul_No_qul_bar_plot(df, bygroup):
    dataframe_by_Group = p.crosstab(df[bygroup], columns=df["Label"], normalize = 'index')
    dataframe_by_Group = n.round((dataframe_by_Group * 100), decimals=2)
    ax = dataframe_by_Group.plot.bar(figsize=(15,7));
    vals = ax.get_yticks()
    ax.set_yticklabels(['{:3.0f}%'.format(x) for x in vals]);
    ax.set_xticklabels(dataframe_by_Group.index,rotation = 0, fontsize = 15);
    ax.set_title('Stock stable or not by given attributes (%) (by ' + dataframe_by_Group.index.name + ')\n', fontsize = 15)
    ax.set_xlabel(dataframe_by_Group.index.name, fontsize = 12)
    ax.set_ylabel('(%)', fontsize = 12)
    ax.legend(loc = 'upper left',bbox_to_anchor=(1.0,1.0), fontsize= 12)
    rects = ax.patches

    # Add Data Labels

    for rect in rects:
        height = rect.get_height()
        ax.text(rect.get_x() + rect.get_width()/2, 
                height + 2, 
                str(height)+'%', 
                ha='center', 
                va='bottom',
                fontsize = 12)
    return dataframe_by_Group

# %%
qul_No_qul_bar_plot(df, 'Subjectivity')
# Out:
# Label              0       1
# Subjectivity
# 0              50.00   50.00
# 1             100.00    0.00
# 10            100.00    0.00
# 100             0.00  100.00
# 101            45.81   54.19
# ...              ...     ...
# 95             47.92   52.08
# 96             50.00   50.00
# 97             60.00   40.00
# 98             43.14   56.86
# 99             38.46   61.54
#
# [121 rows x 2 columns]
